# %% [markdown]
# ### Bring up the API server using the following

# %% [markdown]
# load docker image using in terminal
# <i/><b/>docker load < df_generator_docker_v1.0.tar.gz</b></i>

# %% [markdown]
# run the docker using <i> <b> docker run df_generator:v1.0 </b> </i>

# %%
import requests
import json
import pandas as pd

# %%
r = requests.post('http://0.0.0.0:5802/model/datagenerator_v1.0')
pd.DataFrame(json.loads(r.text))
# Out:
#     feature_1  feature_2  feature_3  feature_4  feature_5
# 0         294        769         44       2030          9
# 1         132        794         20       9119          3
# 2         144        716         16       3476          1
# 3         387        775         67       1791          7
# 4         498        701         44       5192          4
# 5         370        714         23       1883          4
# 6         365        892         86       3492          8
# 7         362        879         26       5311          4
# 8         233        821         37       1899          5
# 9         564        763         34       8852          4
# 10        669        767         35       9288          9
# 11        483        741         55       6599          4
# 12        699        846         84       3026          6
# 13        317        768         76       7656          2
# 14        498        860         72       5278          1
# 15        661        796         79       4512          6
# 16        296        815         10       4911          5
# 17        746        776         35       1029          6
# 18        776        730         36       7436          3
# 19        239        782         10       3564          1
# 20        337        778         15       7741          1
# 21        434        703         23       2343          2
# 22        121        756         86       7974          5
# 23        380        799         81       6352          7
# 24        108        896         33       3733          2
# 25        326        777         16       8467          4
# 26        701        867         10       8924          5
# 27        233        838         83       6672          4
# 28        900        766         84       8044          7
# 29        706        704         46       4611          6
# 30        426        717         88       7305          3
# 31        245        839         38       8813          3
# 32        229        737         74       1038          8
# 33        731        884         86       6224          5
# 34        179        722         95       3035          7
# 35        569        853         63       7666          9
# 36        124        804         81       6685          5
# 37        917        869         44       3348          9
# 38        206        866         38       8852          9
# 39        522        759         80       1022          3
# 40        781        751         57       8667          9
# 41        240        702         87       7696          5
# 42        643        861         22       5995          9
# 43        946        896         51       8309          1
# 44        171        848         39       2252          2
# 45        580        807         28       4195          5
# 46        514        881         17       1377          9
# 47        934        842         69       1676          9
# 48        328        736         71       4508          5
# 49        812        755         49       1000          4
